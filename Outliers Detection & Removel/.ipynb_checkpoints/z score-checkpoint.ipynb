# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv',usecols=['Age','Fare','Survived'])

# %%
df.dropna(inplace=True)

# %%
df['Age'].hist(density=True)
df['Age'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Fare'].hist(density=True)
df['Fare'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.455808097479497

# %%
df['Fare'].skew()
# Out:
# 3.2942383352099363

# %%
print("Mean value of Age",df['Age'].mean())
print("Std value of Age",df['Age'].std())
print("Min value of Age",df['Age'].min())
print("Max value of Age",df['Age'].max())
# Out:
# Mean value of Age 30.181268882175228
# Std value of Age 14.104572594801613
# Min value of Age 0.17
# Max value of Age 76.0
